# %% [markdown]
# ### Classify images of clothing using Fashion MNIST dataset

# %% [markdown]
# Dataset:
# [Fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist) is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. Zalando intends Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2024-10-28 13:29:18.462434: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.1

# %% [markdown]
# ### Step 1: Import MNIST dataset

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
# * The `train_images` and `train_labels` arrays are the *training set*—the data the model uses to learn.
# * The model is tested against the *test set*, the `test_images`, and `test_labels` arrays.
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. The *labels* are an array of integers, ranging from 0 to 9. These correspond to the *class* of clothing the image represents:
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Step 2: Expore the data

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# ### Step 3: Preprocess the data

# %% [markdown]
# The data must be preprocessed before training the network. For example, if we take the first image in the training set, we will see that the pixel values fall in the range of 0 to 255:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Scale these values to a range of 0 to 1 before feeding them to the neural network model. To do so, divide the values by 255. It's important that the training set and the testing set be preprocessed in the same way:

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# To verify that the data is in the correct format and that you're ready to build and train the network, let's display the first 25 images from the training set and display the class name below each image.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Step 4: Build the model

# %% [markdown]
# ### Set up the layers
#
# The basic building block of a neural network is the [*layer*](https://www.tensorflow.org/api_docs/python/tf/keras/layers). Layers extract representations from the data fed into them. Hopefully, these representations are meaningful for the problem at hand.
#
# Most of deep learning consists of chaining together simple layers. Most layers, such as `tf.keras.layers.Dense`, have parameters that are learned during training.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# The first layer in this network, tf.keras.layers.Flatten, transforms the format of the images from a two-dimensional array (of 28 by 28 pixels) to a one-dimensional array (of 28 * 28 = 784 pixels). Think of this layer as unstacking rows of pixels in the image and lining them up. This layer has no parameters to learn; it only reformats the data.
#
# After the pixels are flattened, the network consists of a sequence of two tf.keras.layers.Dense layers. These are densely connected, or fully connected, neural layers. The first Dense layer has 128 nodes (or neurons). The second (and last) layer returns a logits array with length of 10. Each node contains a score that indicates the current image belongs to one of the 10 classes.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model3 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model4 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# ### Step 5: Compile the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model3.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model4.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Step 6: Train the model

# %%
# Train the model and save the training history
history1 = model.fit(train_images, train_labels, epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.4979 - accuracy: 0.8244
# Epoch 2/15
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3732 - accuracy: 0.8669
# Epoch 3/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3397 - accuracy: 0.8762
# Epoch 4/15
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.3152 - accuracy: 0.8852
# Epoch 5/15
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2973 - accuracy: 0.8900
# Epoch 6/15
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2806 - accuracy: 0.8967
# Epoch 7/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2712 - accuracy: 0.8994
# Epoch 8/15
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2590 - accuracy: 0.9040
# Epoch 9/15
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2496 - accuracy: 0.9071
# Epoch 10/15
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2426 - accuracy: 0.9096
# Epoch 11/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.2310 - accuracy: 0.9134
# Epoch 12/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2259 - accuracy: 0.9150
# Epoch 13/15
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2175 - accuracy: 0.9195
# Epoch 14/15
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2124 - accuracy: 0.9205
# Epoch 15/15
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2044 - accuracy: 0.9228

# %%
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history1.history['accuracy'], label='Training Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history1.history['loss'], label='Training Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
# Train the model and save the training history
history2 = model2.fit(train_images, train_labels, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5024 - accuracy: 0.8238
# Epoch 2/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3796 - accuracy: 0.8638
# Epoch 3/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3403 - accuracy: 0.8771
# Epoch 4/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3173 - accuracy: 0.8838
# Epoch 5/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2989 - accuracy: 0.8898
# Epoch 6/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2839 - accuracy: 0.8951
# Epoch 7/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2691 - accuracy: 0.8991
# Epoch 8/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2564 - accuracy: 0.9050
# Epoch 9/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2481 - accuracy: 0.9071
# Epoch 10/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2391 - accuracy: 0.9102
# Epoch 11/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2302 - accuracy: 0.9141
# Epoch 12/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2239 - accuracy: 0.9147
# Epoch 13/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2150 - accuracy: 0.9196
# Epoch 14/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2099 - accuracy: 0.9219
# Epoch 15/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2043 - accuracy: 0.9233
# Epoch 16/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1964 - accuracy: 0.9265
# Epoch 17/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1914 - accuracy: 0.9284
# Epoch 18/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1868 - accuracy: 0.9302
# Epoch 19/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1823 - accuracy: 0.9319
# Epoch 20/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1763 - accuracy: 0.9333
# Epoch 21/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1726 - accuracy: 0.9357
# Epoch 22/50
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1693 - accuracy: 0.9357
# Epoch 23/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1659 - accuracy: 0.9373
# Epoch 24/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1597 - accuracy: 0.9411
# Epoch 25/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1571 - accuracy: 0.9400
# Epoch 26/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1539 - accuracy: 0.9412
# Epoch 27/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1487 - accuracy: 0.9436
# Epoch 28/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1474 - accuracy: 0.9445
# Epoch 29/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1435 - accuracy: 0.9453
# Epoch 30/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1388 - accuracy: 0.9482
# Epoch 31/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1371 - accuracy: 0.9490
# Epoch 32/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1336 - accuracy: 0.9497
# Epoch 33/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1313 - accuracy: 0.9501
# Epoch 34/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1273 - accuracy: 0.9518
# Epoch 35/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1256 - accuracy: 0.9520
# Epoch 36/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1234 - accuracy: 0.9534
# Epoch 37/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1212 - accuracy: 0.9547
# Epoch 38/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1187 - accuracy: 0.9551
# Epoch 39/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1204 - accuracy: 0.9551
# Epoch 40/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1153 - accuracy: 0.9574
# Epoch 41/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1113 - accuracy: 0.9575
# Epoch 42/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1087 - accuracy: 0.9591
# Epoch 43/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1099 - accuracy: 0.9572
# Epoch 44/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1059 - accuracy: 0.9605
# Epoch 45/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1030 - accuracy: 0.9613
# Epoch 46/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1019 - accuracy: 0.9609
# Epoch 47/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1014 - accuracy: 0.9619
# Epoch 48/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0994 - accuracy: 0.9628
# Epoch 49/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0986 - accuracy: 0.9630
# Epoch 50/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0967 - accuracy: 0.9636

# %%
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history2.history['loss'], label='Training Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
# Train the model and save the training history
history3 = model3.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.5041 - accuracy: 0.8237
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3793 - accuracy: 0.8640
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3393 - accuracy: 0.8760
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3152 - accuracy: 0.8844
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2993 - accuracy: 0.8881
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2831 - accuracy: 0.8965
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2708 - accuracy: 0.8996
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2597 - accuracy: 0.9039
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2491 - accuracy: 0.9084
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2422 - accuracy: 0.9096

# %%
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history3.history['accuracy'], label='Training Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history3.history['loss'], label='Training Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
# Train the model and save the training history
history4 = model4.fit(train_images, train_labels, epochs=8)
# Out:
# Epoch 1/8
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4950 - accuracy: 0.8255
# Epoch 2/8
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3730 - accuracy: 0.8643
# Epoch 3/8
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3348 - accuracy: 0.8785
# Epoch 4/8
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3126 - accuracy: 0.8860
# Epoch 5/8
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2936 - accuracy: 0.8924
# Epoch 6/8
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2792 - accuracy: 0.8970
# Epoch 7/8
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2644 - accuracy: 0.9019
# Epoch 8/8
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2566 - accuracy: 0.9047

# %% [markdown]
# ### Step 7: Evaluate Accuracy

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3431 - accuracy: 0.8867 - 1s/epoch - 4ms/step
#
# Test accuracy: 0.8866999745368958

# %%
test_loss, test_acc = model2.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.5111 - accuracy: 0.8889 - 952ms/epoch - 3ms/step
#
# Test accuracy: 0.8888999819755554

# %%
test_loss, test_acc = model3.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3237 - accuracy: 0.8842 - 981ms/epoch - 3ms/step
#
# Test accuracy: 0.8841999769210815

# %%
test_loss, test_acc = model4.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.3360 - accuracy: 0.8821 - 1s/epoch - 4ms/step
#
# Test accuracy: 0.882099986076355

# %%
### Step 8: Make Predictions

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
